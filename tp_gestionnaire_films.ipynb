# %% [markdown]
# # TP Python — Le gestionnaire de films
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — juin 2025**
#
# ---
#
# ## Objectif
#
# Créer une mini-application console qui permet de gérer une collection de films stockée dans un fichier `movies.csv`.
#
# Les utilisateurs peuvent ajouter, supprimer, afficher et rechercher des films, avec un menu interactif et une sauvegarde automatique.
#
# > **Note :** les films sont une suggestion. Si tu préfères stocker d'autres entités comme des musiques, jeux de société... libre à toi !

# %% [markdown]
# ---
#
# ## Étape 1 — Import des modules

# %%
import csv
import os
import json

# %% [markdown]
# ---
#
# ## Étape 2 — Créer le fichier movies.csv
#
# Crée une fonction `creer_fichier_si_absent()` qui génère le fichier `movies.csv` s'il n'existe pas déjà.
#
# Le fichier doit contenir les colonnes suivantes :
#
# | title | release_year | genre | is_seen |
# |-------|-------------|-------|--------|
# | Inception | 2010 | SF | yes |
# | Titanic | 1997 | Romance | yes |

# %%
def creer_fichier_si_absent():
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 3 — Fonctions principales
#
# ### 3.1 — Ajouter un film
#
# Écris une fonction `add_movie()` qui demande les infos à l'utilisateur et ajoute une ligne au fichier CSV.

# %%
def add_movie():
    # À compléter
    pass

# %% [markdown]
# ### 3.2 — Lister les films
#
# Écris une fonction `list_movies()` qui lit le CSV et affiche joliment la liste.

# %%
def list_movies():
    # À compléter
    pass

# %% [markdown]
# ### 3.3 — Rechercher un film
#
# Écris une fonction `search_movie()` qui cherche un titre (insensible à la casse).

# %%
def search_movie():
    # À compléter
    pass

# %% [markdown]
# ### 3.4 — Supprimer un film
#
# Écris une fonction `delete_movie()` qui supprime une entrée du CSV.

# %%
def delete_movie():
    # À compléter
    pass

# %% [markdown]
# ### 3.5 — Marquer comme vu
#
# Écris une fonction `mark_movie_as_seen()` qui modifie le champ `is_seen` à `yes`.

# %%
def mark_movie_as_seen():
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 4 — Menu principal
#
# Écris une fonction `menu()` qui affiche le menu et redirige vers les bonnes fonctions.

# %%
def menu():
    # À compléter
    pass


menu()

# %% [markdown]
# ---
#
# ## Étape 5 — Bonus : export JSON et statistiques
#
# ### 5.1 — Exporter en JSON
#
# Exporte la liste complète des films dans un fichier `movies.json`.

# %%
def exporter_json():
    # À compléter
    pass

# %% [markdown]
# ### 5.2 — Statistiques
#
# Crée un fichier `stats.json` contenant :
# - Nombre total de films
# - Nombre de films vus / non vus
# - Genres les plus représentés

# %%
def creer_stats_json():
    # À compléter
    pass
